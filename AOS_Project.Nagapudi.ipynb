# %% [markdown]
#    <h2>Algorithms</h2>

# %%
from __future__ import print_function
from datetime import datetime
import psutil
import datetime
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import glob
import pandas as pd
import os
import multiprocessing as mp
import json
import os.path
import re  
import time
from multiprocessing import Process
import threading

# Performing NB
def NB():
    from sklearn.naive_bayes import BernoulliNB
    from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, log_loss, roc_auc_score
    from sklearn.model_selection import train_test_split

    import pandas as pd
    import numpy as np
    import random

    from sklearn.utils import shuffle
    print("Naive Bayes Classifier Metrics:")

    columns = ['stime', 'sport', 'dport', 'pkts', 'bytes', 'ltime', 'seq', 
            'dur', 'mean', 'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes', 'dbytes',
            'rate', 'srate', 'drate', 'attack']
    df = pd.read_csv("C:/Users/harsh/Sem2 - TTU/5352-001- Advanced Operating Systems Design/Project/Data_exfiltration.csv", delimiter=';')
    dataset = shuffle(df.filter(columns))

    # input
    x = dataset.iloc[:, [0, 18]].values
  
    # output
    y = dataset.iloc[:, -1].values

    random.seed(121)
    X_train, X_test, Y_train, Y_test = train_test_split(
        x, y, test_size = 0.2, random_state = 42)
    bnb = BernoulliNB()
    bnb.fit(X_train, Y_train)
    Y_pred = bnb.predict(X_test)

    # Calculating Metrics
    cm = confusion_matrix(Y_test, Y_pred)
    ac = accuracy_score(Y_test, Y_pred)
    pr = precision_score(Y_test, Y_pred)
    re = recall_score(Y_test, Y_pred)
    f1 = f1_score(Y_test, Y_pred)
    lolo = log_loss(Y_test, Y_pred)
    rasc = roc_auc_score(Y_test, Y_pred)

    # Displaying Metrics
    # print("Confusion Matrix: {}".format(cm))
    print("Accuracy: {}".format(ac))
    print("Precision: {}".format(pr))
    print("Recall: {}".format(re))
    print("F1 Score: {}".format(f1))
    print("Log Loss: {}".format(lolo))
    print("ROC AUC: {}".format(rasc))

# Performing ANN
def ANN():
    from typing import Type
    from numpy import array
    import tensorflow as tf
    from keras.models import Sequential
    import pandas as pd
    from keras.layers import Dense
    from keras import metrics
    import random
    from tensorflow.python import keras

    from sklearn.utils import shuffle
    print("ANN Classifier Metrics:")

    columns = ['stime', 'sport', 'dport', 'pkts', 'bytes', 'ltime', 'seq', 
            'dur', 'mean', 'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes', 'dbytes',
            'rate', 'srate', 'drate', 'attack']
    df = pd.read_csv("C:/Users/harsh/Sem2 - TTU/5352-001- Advanced Operating Systems Design/Project/Data_exfiltration.csv", delimiter=';')
    dataset = shuffle(df.filter(columns))

    from sklearn.model_selection import train_test_split
    # input
    x = dataset.iloc[:, [0, 18]].values
  
    # output
    y = dataset.iloc[:, -1].values

    random.seed(121)
    from sklearn.model_selection import train_test_split
    xtrain, xtest, ytrain, ytest = train_test_split(
        x, y, test_size = 0.2, random_state = 0)

    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler().fit(xtrain)
    xtrain = scaler.transform(xtrain)
    xtest = scaler.transform(xtest)  

    from keras.models import Sequential
    from keras.layers import Dense
    model = Sequential()
    model.add(Dense(8, input_dim=2, activation='relu' ))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    from keras import backend as K

    def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    def f1_m(y_true, y_pred):
        precision = precision_m(y_true, y_pred)
        recall = recall_m(y_true, y_pred)
        return 2*((precision*recall)/(precision+recall+K.epsilon()))

    model.compile(loss='binary_crossentropy',
    optimizer='sgd',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), f1_m, tf.keras.metrics.AUC()])
    model.fit(xtrain, ytrain, epochs=4, batch_size=1, verbose=1)

    y_pred = model.predict(xtest)

    lolo, ac, pr, re, f1, rasc = model.evaluate(xtest, ytest,verbose=1)

    # Displaying Metrics
    # print("Confusion Matrix: {}".format(cm))
    print("Accuracy: {}".format(ac))
    print("Precision: {}".format(pr))
    print("Recall: {}".format(re))
    print("F1 Score: {}".format(f1))
    print("Log Loss: {}".format(lolo))
    print("ROC AUC: {}".format(rasc)) 
    
    sys.stdout.flush()

# %% [markdown]
#    <h2>Program A Alone - NB</h2>

# %%
#Algorithm A Alone
print("\033[1m""Algorithm A i.e., NB Alone:""\033[0m")
#Starting Time
start = time.time()
NB()
#Ending Time
end = time.time()

#User-Level Info
print("\033[1m""User-Level Info: ""\033[0m")
#Total time taken
print("Running time for Program A is: ", end-start)

#System-level Info
print("\033[1m""System-Level Info: ""\033[0m")

#logical cores= #physical cores * #threads of each core (Hyper thread)
cpulc=psutil.cpu_count(logical=True)
print("Logical Cores:", cpulc)
#return the number of physical cores only
cpupc=psutil.cpu_count(logical=False)
print("Physical Cores:", cpupc)

#CPU Usage
e=psutil.cpu_percent()
print("CPU Utilization:", e)

#Memory Usage 
dict(psutil.virtual_memory()._asdict())
# percentage of used RAM
print("Used RAM: ", psutil.virtual_memory().percent)
# percentage of available memory
print("Available Memory: ", psutil.virtual_memory().available * 100 / psutil.virtual_memory().total)

#Hard Drive Usage
du=psutil.disk_usage("/")
print("Hard drive usage:", du.percent)

#RSS, VMS, Pagefaults
pid=os.getpid()
py=psutil.Process(pid)
p=py.memory_full_info()
print("RSS:",p.rss)
print("VMS:",p.vms)
print("Page faults:",p.num_page_faults)
# Out:
# Algorithm A i.e., NB Alone:
# Naive Bayes Classifier Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Log Loss: 9.992007221626413e-16
# ROC AUC: 1.0
# User-Level Info:
# Running time for Program A is:  0.01538705825805664
# System-Level Info:
# Logical Cores: 8
# Physical Cores: 4
# CPU Utilization: 5.1
# Used RAM:  63.5
# Available Memory:  36.51204139801168
# Hard drive usage: 29.2
# RSS: 480731136
# VMS: 735866880
# Page faults: 785299

# %% [markdown]
#    <h2>Program B Alone - ANN</h2>

# %%
#Algorithm B Alone
print("\033[1m""Algorithm B i.e., ANN Alone:""\033[0m")
#Starting Time
start = time.time()
ANN()
#Ending Time
end = time.time()

#User-Level Info
print("\033[1m""User-Level Info: ""\033[0m")
#Total time taken
print("Running time for Program B is: ", end-start)

#System-level Info
print("\033[1m""System-Level Info: ""\033[0m")

#logical cores= #physical cores * #threads of each core (Hyper thread)
cpulc=psutil.cpu_count(logical=True)
print("Logical Cores:", cpulc)
#return the number of physical cores only
cpupc=psutil.cpu_count(logical=False)
print("Physical Cores:", cpupc)

#CPU Usage
e=psutil.cpu_percent()
print("CPU Utilization:", e)

#Memory Usage 
dict(psutil.virtual_memory()._asdict())
# percentage of used RAM
print("Used RAM: ", psutil.virtual_memory().percent)
# percentage of available memory
print("Available Memory: ", psutil.virtual_memory().available * 100 / psutil.virtual_memory().total)

#Hard Drive Usage
du=psutil.disk_usage("/")
print("Hard drive usage:", du.percent)

#RSS, VMS, Pagefaults
pid=os.getpid()
py=psutil.Process(pid)
p=py.memory_full_info()
print("RSS:",p.rss)
print("VMS:",p.vms)
print("Page faults:",p.num_page_faults)
# Out:
# Algorithm B i.e., ANN Alone:
# ANN Classifier Metrics:
# Epoch 1/4
# 113/113 [==============================] - 1s 1ms/step - loss: 0.6093 - accuracy: 0.8230 - precision_65: 0.8230 - recall_65: 1.0000 - f1_m: 0.8230 - auc_65: 0.3823
# Epoch 2/4
# 113/113 [==============================] - 0s 938us/step - loss: 0.5230 - accuracy: 0.8230 - precision_65: 0.8230 - recall_65: 1.0000 - f1_m: 0.8230 - auc_65: 0.5202
# Epoch 3/4
# 113/113 [==============================] - 0s 932us/step - loss: 0.4753 - accuracy: 0.8230 - precision_65: 0.8230 - recall_65: 1.0000 - f1_m: 0.8230 - auc_65: 0.7355
# Epoch 4/4
# 113/113 [==============================] - 0s 879us/step - loss: 0.4410 - accuracy: 0.8230 - precision_65: 0.8230 - recall_65: 1.0000 - f1_m: 0.8230 - auc_65: 0.8737
# 1/1 [==============================] - 0s 298ms/step - loss: 0.3826 - accuracy: 0.8621 - precision_65: 0.8621 - recall_65: 1.0000 - f1_m: 0.9259 - auc_65: 0.8950
# Accuracy: 0.8620689511299133
# Precision: 0.8620689511299133
# Recall: 1.0
# F1 Score: 0.9259258508682251
# Log Loss: 0.382583886384964
# ROC AUC: 0.8949999809265137
# User-Level Info:
# Running time for Program B is:  1.7341728210449219
# System-Level Info:
# Logical Cores: 8
# Physical Cores: 4
# CPU Utilization: 4.0
# Used RAM:  63.4
# Available Memory:  36.60201033137316
# Hard drive usage: 29.2
# RSS: 473190400
# VMS: 727711744
# Page faults: 785845

# %% [markdown]
#    <h2>Program A and B Concurrently - NB and ANN</h2>

# %%
#Algorithm A and B Concurrently
print("\033[1m""Algorithm A and B i.e., NB and ANN Concurrently:""\033[0m")
#Starting Time
start = time.time()
if __name__ == '__main__':
    p1 = threading.Thread(target=NB)
    p1.start()
    p2 = threading.Thread(target=ANN)
    p2.start()
    p1.join()
    p2.join()
#Ending Time
end = time.time()

#User-Level Info
print("\033[1m""User-Level Info: ""\033[0m")
#Total time taken
print("Running time for Programs A and B is: ", end-start)

#System-level Info
print("\033[1m""System-Level Info: ""\033[0m")

#logical cores= #physical cores * #threads of each core (Hyper thread)
cpulc=psutil.cpu_count(logical=True)
print("Logical Cores:", cpulc)
#return the number of physical cores only
cpupc=psutil.cpu_count(logical=False)
print("Physical Cores:", cpupc)

#CPU Usage
e=psutil.cpu_percent()
print("CPU Utilization:", e)

#Memory Usage 
dict(psutil.virtual_memory()._asdict())
# percentage of used RAM
print("Used RAM: ", psutil.virtual_memory().percent)
# percentage of available memory
print("Available Memory: ", psutil.virtual_memory().available * 100 / psutil.virtual_memory().total)

#Hard Drive Usage
du=psutil.disk_usage("/")
print("Hard drive usage:", du.percent)

#RSS, VMS, Pagefaults
pid=os.getpid()
py=psutil.Process(pid)
p=py.memory_full_info()
print("RSS:",p.rss)
print("VMS:",p.vms)
print("Page faults:",p.num_page_faults)
# Out:
# Algorithm A and B i.e., NB and ANN Concurrently:
# Naive Bayes Classifier Metrics:
# ANN Classifier Metrics:
# Accuracy: 0.9310344827586207
# Precision: 0.9166666666666666
# Recall: 1.0
# F1 Score: 0.9565217391304348
# Log Loss: 2.3820397236097164
# ROC AUC: 0.8571428571428572
# Epoch 1/4
# 113/113 [==============================] - 1s 1ms/step - loss: 0.5546 - accuracy: 0.8407 - precision: 0.9043 - recall: 0.9043 - f1_m: 0.7522 - auc: 0.8390
# Epoch 2/4
# 113/113 [==============================] - 0s 911us/step - loss: 0.4097 - accuracy: 0.8673 - precision: 0.8762 - recall: 0.9787 - f1_m: 0.8142 - auc: 0.8645
# Epoch 3/4
# 113/113 [==============================] - 0s 1ms/step - loss: 0.3604 - accuracy: 0.8673 - precision: 0.8762 - recall: 0.9787 - f1_m: 0.8142 - auc: 0.9244
# Epoch 4/4
# 113/113 [==============================] - 0s 919us/step - loss: 0.3300 - accuracy: 0.8673 - precision: 0.8762 - recall: 0.9787 - f1_m: 0.8142 - auc: 0.8628
# 1/1 [==============================] - 0s 286ms/step - loss: 0.2419 - accuracy: 0.8966 - precision: 0.8889 - recall: 1.0000 - f1_m: 0.9412 - auc: 1.0000
# Accuracy: 0.8965517282485962
# Precision: 0.8888888955116272
# Recall: 1.0
# F1 Score: 0.9411764144897461
# Log Loss: 0.2418522983789444
# ROC AUC: 1.0
# User-Level Info:
# Running time for Programs A and B is:  1.5328223705291748
# System-Level Info:
# Logical Cores: 8
# Physical Cores: 4
# CPU Utilization: 11.1
# Used RAM:  63.4
# Available Memory:  36.61207882301599
# Hard drive usage: 29.2
# RSS: 473751552
# VMS: 727822336
# Page faults: 786453
