# %% [markdown]
#    <h2>Algorithms</h2>

# %%
from __future__ import print_function
from datetime import datetime
import psutil
import datetime
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import glob
import pandas as pd
import os
import multiprocessing as mp
import json
import os.path
import re  
import time

# Performing NB
def NB():
    from sklearn.naive_bayes import BernoulliNB
    from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, log_loss, roc_auc_score
    from sklearn.model_selection import train_test_split

    import pandas as pd
    import numpy as np
    import random

    from sklearn.utils import shuffle
    print("Naive Bayes Classifier Metrics:")

    columns = ['stime', 'sport', 'dport', 'pkts', 'bytes', 'ltime', 'seq', 
            'dur', 'mean', 'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes', 'dbytes',
            'rate', 'srate', 'drate', 'attack']
    df = pd.read_csv("C:/Users/harsh/Sem2 - TTU/5352-001- Advanced Operating Systems Design/Project/Data_exfiltration.csv", delimiter=';')
    dataset = shuffle(df.filter(columns))

    # input
    x = dataset.iloc[:, [0, 18]].values
  
    # output
    y = dataset.iloc[:, -1].values

    random.seed(121)
    X_train, X_test, Y_train, Y_test = train_test_split(
        x, y, test_size = 0.2, random_state = 42)
    bnb = BernoulliNB()
    bnb.fit(X_train, Y_train)
    Y_pred = bnb.predict(X_test)

    # Calculating Metrics
    cm = confusion_matrix(Y_test, Y_pred)
    ac = accuracy_score(Y_test, Y_pred)
    pr = precision_score(Y_test, Y_pred)
    re = recall_score(Y_test, Y_pred)
    f1 = f1_score(Y_test, Y_pred)
    lolo = log_loss(Y_test, Y_pred)
    rasc = roc_auc_score(Y_test, Y_pred)

    # Displaying Metrics
    # print("Confusion Matrix: {}".format(cm))
    print("Accuracy: {}".format(ac))
    print("Precision: {}".format(pr))
    print("Recall: {}".format(re))
    print("F1 Score: {}".format(f1))
    print("Log Loss: {}".format(lolo))
    print("ROC AUC: {}".format(rasc))

# Performing ANN
def ANN():
    from typing import Type
    from numpy import array
    import tensorflow as tf
    from keras.models import Sequential
    import pandas as pd
    from keras.layers import Dense
    from keras import metrics
    import random
    from tensorflow.python import keras

    from sklearn.utils import shuffle
    print("ANN Classifier Metrics:")

    columns = ['stime', 'sport', 'dport', 'pkts', 'bytes', 'ltime', 'seq', 
            'dur', 'mean', 'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes', 'dbytes',
            'rate', 'srate', 'drate', 'attack']
    df = pd.read_csv("C:/Users/harsh/Sem2 - TTU/5352-001- Advanced Operating Systems Design/Project/Data_exfiltration.csv", delimiter=';')
    dataset = shuffle(df.filter(columns))

    from sklearn.model_selection import train_test_split
    # input
    x = dataset.iloc[:, [0, 18]].values
  
    # output
    y = dataset.iloc[:, -1].values

    random.seed(121)
    from sklearn.model_selection import train_test_split
    xtrain, xtest, ytrain, ytest = train_test_split(
        x, y, test_size = 0.2, random_state = 0)

    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler().fit(xtrain)
    xtrain = scaler.transform(xtrain)
    xtest = scaler.transform(xtest)  

    from keras.models import Sequential
    from keras.layers import Dense
    model = Sequential()
    model.add(Dense(8, input_dim=2, activation='relu' ))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    from keras import backend as K

    def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    def f1_m(y_true, y_pred):
        precision = precision_m(y_true, y_pred)
        recall = recall_m(y_true, y_pred)
        return 2*((precision*recall)/(precision+recall+K.epsilon()))

    model.compile(loss='binary_crossentropy',
    optimizer='sgd',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), f1_m, tf.keras.metrics.AUC()])
    model.fit(xtrain, ytrain, epochs=4, batch_size=1, verbose=1)

    y_pred = model.predict(xtest)

    lolo, ac, pr, re, f1, rasc = model.evaluate(xtest, ytest,verbose=1)

    # Displaying Metrics
    # print("Confusion Matrix: {}".format(cm))
    print("Accuracy: {}".format(ac))
    print("Precision: {}".format(pr))
    print("Recall: {}".format(re))
    print("F1 Score: {}".format(f1))
    print("Log Loss: {}".format(lolo))
    print("ROC AUC: {}".format(rasc))

# %% [markdown]
#    <h2>Program A Alone - NB</h2>

# %%
#Algorithm A Alone
print("\033[1m""Algorithm A i.e., NB Alone:""\033[0m")
#Starting Time
start = time.time()
NB()
#Ending Time
end = time.time()

#User-Level Info
print("\033[1m""User-Level Info: ""\033[0m")
#Total time taken
print("Running time for Program A is: ", end-start)

#System-level Info
print("\033[1m""System-Level Info: ""\033[0m")

#logical cores= #physical cores * #threads of each core (Hyper thread)
cpulc=psutil.cpu_count(logical=True)
print("Logical Cores:", cpulc)
#return the number of physical cores only
cpupc=psutil.cpu_count(logical=False)
print("Physical Cores:", cpupc)

#CPU Usage
e=psutil.cpu_percent()
print("CPU Utilization:", e)

#Memory Usage 
dict(psutil.virtual_memory()._asdict())
# percentage of used RAM
print("Used RAM: ", psutil.virtual_memory().percent)
# percentage of available memory
print("Available Memory: ", psutil.virtual_memory().available * 100 / psutil.virtual_memory().total)

#Hard Drive Usage
du=psutil.disk_usage("/")
print("Hard drive usage:", du.percent)

#RSS, VMS, Pagefaults
pid=os.getpid()
py=psutil.Process(pid)
p=py.memory_full_info()
print("RSS:",p.rss)
print("VMS:",p.vms)
print("Page faults:",p.num_page_faults)
# Out:
# Algorithm A i.e., NB Alone:
# Naive Bayes Classifier Metrics:
# Accuracy: 0.9310344827586207
# Precision: 0.92
# Recall: 1.0
# F1 Score: 0.9583333333333334
# Log Loss: 2.3820397236097164
# ROC AUC: 0.8333333333333334
# User-Level Info:
# Running time for Program A is:  0.013186216354370117
# System-Level Info:
# Logical Cores: 8
# Physical Cores: 4
# CPU Utilization: 4.7
# Used RAM:  64.1
# Available Memory:  35.860341279779746
# Hard drive usage: 29.2
# RSS: 422760448
# VMS: 681873408
# Page faults: 717242

# %% [markdown]
#    <h2>Program B Alone - ANN</h2>

# %%
#Algorithm B Alone
print("\033[1m""Algorithm B i.e., ANN Alone:""\033[0m")
#Starting Time
start = time.time()
ANN()
#Ending Time
end = time.time()

#User-Level Info
print("\033[1m""User-Level Info: ""\033[0m")
#Total time taken
print("Running time for Program B is: ", end-start)

#System-level Info
print("\033[1m""System-Level Info: ""\033[0m")

#logical cores= #physical cores * #threads of each core (Hyper thread)
cpulc=psutil.cpu_count(logical=True)
print("Logical Cores:", cpulc)
#return the number of physical cores only
cpupc=psutil.cpu_count(logical=False)
print("Physical Cores:", cpupc)

#CPU Usage
e=psutil.cpu_percent()
print("CPU Utilization:", e)

#Memory Usage 
dict(psutil.virtual_memory()._asdict())
# percentage of used RAM
print("Used RAM: ", psutil.virtual_memory().percent)
# percentage of available memory
print("Available Memory: ", psutil.virtual_memory().available * 100 / psutil.virtual_memory().total)

#Hard Drive Usage
du=psutil.disk_usage("/")
print("Hard drive usage:", du.percent)

#RSS, VMS, Pagefaults
pid=os.getpid()
py=psutil.Process(pid)
p=py.memory_full_info()
print("RSS:",p.rss)
print("VMS:",p.vms)
print("Page faults:",p.num_page_faults)
# Out:
# Algorithm B i.e., ANN Alone:
# ANN Classifier Metrics:
# Epoch 1/4
# 113/113 [==============================] - 1s 1ms/step - loss: 0.6554 - accuracy: 0.7434 - precision_41: 0.8462 - recall_41: 0.8370 - f1_m: 0.6814 - auc_41: 0.4410
# Epoch 2/4
# 113/113 [==============================] - 0s 866us/step - loss: 0.5536 - accuracy: 0.8053 - precision_41: 0.8125 - recall_41: 0.9891 - f1_m: 0.8053 - auc_41: 0.8328
# Epoch 3/4
# 113/113 [==============================] - 0s 922us/step - loss: 0.4891 - accuracy: 0.8053 - precision_41: 0.8125 - recall_41: 0.9891 - f1_m: 0.8053 - auc_41: 0.9110
# Epoch 4/4
# 113/113 [==============================] - 0s 919us/step - loss: 0.4409 - accuracy: 0.8407 - precision_41: 0.8426 - recall_41: 0.9891 - f1_m: 0.8053 - auc_41: 0.9105
# 1/1 [==============================] - 0s 290ms/step - loss: 0.3993 - accuracy: 0.8621 - precision_41: 0.8929 - recall_41: 0.9615 - f1_m: 0.9259 - auc_41: 0.9231
# Accuracy: 0.8620689511299133
# Precision: 0.8928571343421936
# Recall: 0.9615384340286255
# F1 Score: 0.9259259104728699
# Log Loss: 0.39928317070007324
# ROC AUC: 0.9230769276618958
# User-Level Info:
# Running time for Program B is:  1.4309887886047363
# System-Level Info:
# Logical Cores: 8
# Physical Cores: 4
# CPU Utilization: 3.6
# Used RAM:  64.3
# Available Memory:  35.73560205695075
# Hard drive usage: 29.2
# RSS: 438390784
# VMS: 696053760
# Page faults: 721512

# %% [markdown]
#    <h2>Program A and B Concurrently - NB and ANN</h2>

# %%
#Algorithm A and B Concurrently
print("\033[1m""Algorithm A and B i.e., NB and ANN Concurrently:""\033[0m")
#Starting Time
start = time.time()
NB()
ANN()
#Ending Time
end = time.time()

#User-Level Info
print("\033[1m""User-Level Info: ""\033[0m")
#Total time taken
print("Running time for Programs A and B is: ", end-start)

#System-level Info
print("\033[1m""System-Level Info: ""\033[0m")

#logical cores= #physical cores * #threads of each core (Hyper thread)
cpulc=psutil.cpu_count(logical=True)
print("Logical Cores:", cpulc)
#return the number of physical cores only
cpupc=psutil.cpu_count(logical=False)
print("Physical Cores:", cpupc)

#CPU Usage
e=psutil.cpu_percent()
print("CPU Utilization:", e)

#Memory Usage 
dict(psutil.virtual_memory()._asdict())
# percentage of used RAM
print("Used RAM: ", psutil.virtual_memory().percent)
# percentage of available memory
print("Available Memory: ", psutil.virtual_memory().available * 100 / psutil.virtual_memory().total)

#Hard Drive Usage
du=psutil.disk_usage("/")
print("Hard drive usage:", du.percent)

#RSS, VMS, Pagefaults
pid=os.getpid()
py=psutil.Process(pid)
p=py.memory_full_info()
print("RSS:",p.rss)
print("VMS:",p.vms)
print("Page faults:",p.num_page_faults)
# Out:
# Algorithm A and B i.e., NB and ANN Concurrently:
# Naive Bayes Classifier Metrics:
# Accuracy: 0.9655172413793104
# Precision: 0.9629629629629629
# Recall: 1.0
# F1 Score: 0.9811320754716981
# Log Loss: 1.1910198618048586
# ROC AUC: 0.8333333333333334
# ANN Classifier Metrics:
# Epoch 1/4
# 113/113 [==============================] - 1s 1ms/step - loss: 0.6051 - accuracy: 0.8850 - precision_42: 0.8952 - recall_42: 0.9792 - f1_m: 0.8319 - auc_42: 0.5401
# Epoch 2/4
# 113/113 [==============================] - 0s 891us/step - loss: 0.5038 - accuracy: 0.8584 - precision_42: 0.8704 - recall_42: 0.9792 - f1_m: 0.8319 - auc_42: 0.5214
# Epoch 3/4
# 113/113 [==============================] - 0s 922us/step - loss: 0.4533 - accuracy: 0.8407 - precision_42: 0.8545 - recall_42: 0.9792 - f1_m: 0.8319 - auc_42: 0.5322
# Epoch 4/4
# 113/113 [==============================] - 0s 833us/step - loss: 0.4206 - accuracy: 0.8496 - precision_42: 0.8624 - recall_42: 0.9792 - f1_m: 0.8319 - auc_42: 0.5662
# 1/1 [==============================] - 0s 290ms/step - loss: 0.4566 - accuracy: 0.8621 - precision_42: 0.8462 - recall_42: 1.0000 - f1_m: 0.9167 - auc_42: 0.8247
# Accuracy: 0.8620689511299133
# Precision: 0.8461538553237915
# Recall: 1.0
# F1 Score: 0.9166666269302368
# Log Loss: 0.45655691623687744
# ROC AUC: 0.8246753215789795
# User-Level Info:
# Running time for Programs A and B is:  1.4474515914916992
# System-Level Info:
# Logical Cores: 8
# Physical Cores: 4
# CPU Utilization: 7.4
# Used RAM:  64.3
# Available Memory:  35.73828914636026
# Hard drive usage: 29.2
# RSS: 455356416
# VMS: 711475200
# Page faults: 726125
